# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrice7921/tibame.aws/blob/main/20251220.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas //在colab裡面已經有裝，其他的要裝

# %%
import json
import urllib.request as req
import pandas as pd

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36632&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
content = json.loads(content)

danmus = content["data"]["danmu"]
# pd: DataFrame表格 Series一列/一行
# json->dataframe
# [{}, {}, {}]
df = pd.DataFrame(danmus)
# 不要列標籤: index=False
df.to_csv("danmu.csv", encoding="utf-8")
df.to_excel("danmu.xlsx")
df
# Out:
#                     text    color  size  position  time        sn  \
# 0                     二刷  #FFFFFF     1         0     0  42903755
# 1                  吉伊卡哇！  #FFFFFF     1         0     0  45641971
# 2                 感謝動畫瘋！  #FFFFFF     1         0     0  45796240
# 3            2025.11.24簽  #FDE53D     1         0     0  47316552
# 4                  吉依好可愛  #FFFFFF     1         0     5  40580321
# ..                   ...      ...   ...       ...   ...       ...
# 524  ˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊ  #FFFFFF     1         0   893  46704569
# 525                    我  #FFFFFF     1         0   897  45779317
# 526                    😀  #00C3FC     1         0   898  40894473
# 527               沒了？？？？  #FFFFFF     1         0   901  42188563
# 528                    哈  #FF0026     1         0   901  44529579
#
#            userid
# 0      qaz1210731
# 1     dodylee0107
# 2          hyg125
# 3      MilkTea157
# 4    KingOrange69
# ..            ...
# 524         swyan
# ...

# %% [markdown]
# ```
# 1. 過濾 : 準備跟資料筆數一樣多的True (保留) / False (刪去)
# 2. 轉換
# ```

# %%
# 顯示資料的前三筆資料
testdf = df.head(3)

# 設定哪幾個欄位要顯示(True會顯示;False會隱藏)
fil = [True,False,True]
testdf[fil]
# Out:
#      text    color  size  position  time        sn      userid
# 0      二刷  #FFFFFF     1         0     0  42903755  qaz1210731
# 2  感謝動畫瘋！  #FFFFFF     1         0     0  45796240      hyg125

# %%
# 1 col
df["text"]
# multiole col
df[["userid", "text"]]
# Out:
#            userid                 text
# 0      qaz1210731                   二刷
# 1     dodylee0107                吉伊卡哇！
# 2          hyg125               感謝動畫瘋！
# 3      MilkTea157          2025.11.24簽
# 4    KingOrange69                吉依好可愛
# ..            ...                  ...
# 524         swyan  ˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊ
# 525      Webb2012                    我
# 526     kekerry75                    😀
# 527        linzzi               沒了？？？？
# 528     st5109185                    哈
#
# [529 rows x 2 columns]

# %%
# value_count 可以計算重複次數
df["userid"].value_counts()
# Out:
# userid
# st5109185       10
# annana566        7
# g840483938       6
# kateihan0307     5
# tsubakilee       4
#                 ..
# yzf8rvkgnk       1
# a631003          1
# karta2194512     1
# dozwang          1
# amy20130605      1
# Name: count, Length: 411, dtype: int64

# %%
target="tsubakilee"
fil = df["userid"] == target
df[fil]
# Out:
#                      text    color  size  position  time        sn      userid
# 157                 我第一次看  #FFFFFF     1         0   221  41164994  tsubakilee
# 172      有人在嗎嘉義\n\n有人在嗎+1  #FFFFFF     1         0   259  41165004  tsubakilee
# 342     有人跟我一樣晚上看嗎\n看了快餓死  #FFFFFF     1         0   576  41165019  tsubakilee
# 416  沒了？？？？？？？？？？？？？？？？？？  #FFFFFF     1         0   693  41165047  tsubakilee

# %%
# 組合符號 & and | or
fil1 = df["time"] >= 100
fil2 = df["time"] <= 890
fil = fil1 & fil2
df[fil]
# Out:
#            text    color  size  position  time        sn        userid
# 71            呀  #FFFFFF     1         0   100  42386189   UwUsb924549
# 72           二刷  #FFFFFF     1         0   101  43860125  inspiration9
# 73            簽  #FFFFFF     1         0   105  40784961  yu2501171025
# 74          羊粑粑  #FFFFFF     1         0   105  44235094       K941119
# 75          ！！！  #FFFFFF     2         0   106  42505502  pink20111129
# ..          ...      ...   ...       ...   ...       ...           ...
# 519         小八💗  #FFFFFF     1         0   874  43182188  yinqiancai02
# 520     泡泡驗超市和看  #FFFFFF     1         0   876  44179856    g840483938
# 521         ZMB  #FFFFFF     1         0   877  42527612       ZED8090
# 522  體感一秒鐘提敢一秒鐘  #FFFFFF     1         0   889  45729097        Mia130
# 523     兄弟有事請轉身  #FFFFFF     1         0   890  44754781      D0690422
#
# [453 rows x 7 columns]

# %% [markdown]
# ```
# Everything is an object
# 任何東西都有型態，每種型態都有自己的操作
#
# list [0]  for ... in .append
#
# 以前: print(3.24)
# 現在: 功能(不加小括號)是一種型態
# print : 刷牙步驟     (3.24)操作後得到結果
#
# ```

# %%
import random
b = int
b(4.6)

def func(mode=0):
    if mode == 0:
        return random.randint
    else:
        return random.uniform

func(0)(6,7) #6到7之間的整數
func(1)(6,7) #6到7之間的小數
# Out:
# 6.067117452197525

# %%
def func(s):
    s_int = int(s)
    s_int_r = round(s_int / 10.0)
    minute = s_int_r // 60
    seconds = s_int_r % 60
    return "{:02d}:{:02d}".format(minute, seconds)

#func(876)
df["time_conv"] = df["time"].apply(func)
df
# 原資料上新增一個轉換後的欄位(保留原欄位)
# Out:
#                     text    color  size  position  time        sn  \
# 0                     二刷  #FFFFFF     1         0     0  42903755
# 1                  吉伊卡哇！  #FFFFFF     1         0     0  45641971
# 2                 感謝動畫瘋！  #FFFFFF     1         0     0  45796240
# 3            2025.11.24簽  #FDE53D     1         0     0  47316552
# 4                  吉依好可愛  #FFFFFF     1         0     5  40580321
# ..                   ...      ...   ...       ...   ...       ...
# 524  ˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊ  #FFFFFF     1         0   893  46704569
# 525                    我  #FFFFFF     1         0   897  45779317
# 526                    😀  #00C3FC     1         0   898  40894473
# 527               沒了？？？？  #FFFFFF     1         0   901  42188563
# 528                    哈  #FF0026     1         0   901  44529579
#
#            userid time_cov time_conv
# 0      qaz1210731    00:00     00:00
# 1     dodylee0107    00:00     00:00
# 2          hyg125    00:00     00:00
# ...

# %%
"{}" .format(str(1).zfill(4)) #補0到四位數
"{:08d}".format(1) #補0到八位數
#0 -> 補甚麼值
#8 -> 補幾位
#d -> 整數
# Out:
# '00000001'

# %% [markdown]
# ```
# 簡單nlp(自然語言處理)
# jieba
#
# TF-IDF:抓重點
# 1. 次數(TF)，多，重要程度越高
# 2. 常見度(IDF)，高，重要程度低
# 重要性 = 次數 * 1/常用度
# ```

# %%
import jieba
import urllib.request as req

url = "http://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big"
req.urlretrieve(url, "big")
jieba.set_dictionary("big")

# %%
import jieba.analyse
s = "台灣最大入口網站，Yahoo奇摩新聞提供跨平台、即時、多元、專業的最新時事動態，讓你隨時隨地瀏覽最新新聞"
jieba.analyse.extract_tags(s)
jieba.add_word("吉伊卡哇")
# Out:
# /usr/local/lib/python3.12/dist-packages/jieba/posseg/__init__.py:16: SyntaxWarning: invalid escape sequence '\.'
#   re_skip_detail = re.compile("([\.0-9]+|[a-zA-Z0-9]+)")
# /usr/local/lib/python3.12/dist-packages/jieba/posseg/__init__.py:17: SyntaxWarning: invalid escape sequence '\.'
#   re_han_internal = re.compile("([\u4E00-\u9FD5a-zA-Z0-9+#&\._]+)")
# /usr/local/lib/python3.12/dist-packages/jieba/posseg/__init__.py:18: SyntaxWarning: invalid escape sequence '\s'
#   re_skip_internal = re.compile("(\r\n|\s)")
# /usr/local/lib/python3.12/dist-packages/jieba/posseg/__init__.py:21: SyntaxWarning: invalid escape sequence '\.'
#   re_num = re.compile("[\.0-9]+")
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 1.520 seconds.
# DEBUG:jieba:Loading model cost 1.520 seconds.
# ...

# %%
def func(s):
    tags = jieba.analyse.extract_tags(s)
    return str(tags)

df["text"].apply(func)
# Out:
# 0                 ['二刷']
# 1               ['吉伊卡哇']
# 2           ['感謝', '動畫']
# 3      ['2025.11', '24']
# 4                ['吉依好']
#              ...
# 524                   []
# 525                   []
# 526                   []
# 527                   []
# 528                   []
# Name: text, Length: 529, dtype: object
