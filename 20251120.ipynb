# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrice7921/tibame.aws/blob/main/20251120.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=3
print(a)
# Out:
# 3

# %% [markdown]
# Latex Math 語法，輕鬆打出漂亮的數學式子
# $\frac{1}{3+\pi}$
